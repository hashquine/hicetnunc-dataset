# %% [markdown]
# ## Load state

# %%
import sys
from pathlib import Path

repo_dir = Path('..').resolve()
assert repo_dir.name == 'hicetnunc-dataset', repo_dir
if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

import src.reload; src.reload.reload()

nft_state_log = src.utils.read_json(src.config.nft_state_log_file)
nft_state = src.contracts.nft_state.NFTState()
nft_state_replayer = src.contracts.state_utils.StateReplayer(nft_state_log, nft_state)

ah_state_log = src.utils.read_json(src.config.ah_state_log_file)
ah_state = src.contracts.art_house_state.ArtHouseState()
ah_state_replayer = src.contracts.state_utils.StateReplayer(ah_state_log, ah_state)

# %% [markdown]
# ## Filter money trs

# %%
money_trs = []

for tr in src.iter_tr.iter_tr():
    tr_volume = 0
    for op in tr['ops']:
        if op['status'] != 'applied':
            continue
        assert op['volume'] >= 0
        tr_volume += op['volume']
    if tr_volume > 0:
        money_trs.append(tr)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:06<00:00,  3.48it/s]

# %% [markdown]
# ## Classify money transactions

# %%
from collections import defaultdict


class MoneyState:
    def __init__(self):
        self.reset()

    def reset(self):
        self.balances = Counter()
        self.addrs = defaultdict(lambda: {
            'total_bought': 0,
            'total_sold': 0,
            'events': [],
        })
        self.tokens = defaultdict(lambda: {
            'events': [],
        })
        self.comission_wallet = {
            'comission_income': 0,
            'percent_income': 0,
            'other_income': 0,
            'spending': 0,
            'events': [],
        }

    def apply_swap_sell(self, row_id, token_id, token_count, payer, beneficiary, price, comission):
        event = {
            'row_id': row_id,
            'type': 'swap_sell',
            'token_id': token_id,
            'token_count': token_count,
            'payer': payer,
            'beneficiary': beneficiary,
            'price': price,
            'comission': comission,
        }
        self.addrs[payer]['total_bought'] += price
        self.addrs[beneficiary]['total_sold'] += price - comission
        self.addrs[payer]['events'].append(event)
        self.addrs[beneficiary]['events'].append(event)
        self.tokens[token_id]['events'].append(event)
        self.comission_wallet['comission_income'] += comission
        self.comission_wallet['events'].append(event)

        self.balances[payer] -= price
        self.balances[beneficiary] += price - comission
        self.balances[src.config.name2addr['comission_wallet']] += comission

    def apply_comission_wallet_baking_percent(self, row_id, sender, volume):
        assert sender == src.config.name2addr['baking_benjamins']
        assert volume > 0
        event = {
            'row_id': row_id,
            'type': 'comission_wallet_baking_percent',
            'sender': sender,
            'receiver': src.config.name2addr['comission_wallet'],
            'volume': volume,
        }
        self.comission_wallet['events'].append(event)
        self.comission_wallet['percent_income'] += volume
        self.balances[src.config.name2addr['baking_benjamins']] -= volume
        self.balances[src.config.name2addr['comission_wallet']] += volume

    def apply_comission_wallet_spending(self, row_id, receiver, volume):
        assert volume > 0
        event = {
            'row_id': row_id,
            'type': 'comission_wallet_spending',
            'sender': src.config.name2addr['comission_wallet'],
            'receiver': sender,
            'volume': volume,
        }
        self.comission_wallet['events'].append(event)
        self.comission_wallet['spending'] += volume    
        self.balances[receiver] += volume
        self.balances[src.config.name2addr['comission_wallet']] -= volume


from collections import Counter

money_state = MoneyState()
money_state = src.contracts.state_utils.StateRecorder(money_state)

for tr in money_trs:

    nft_calls = Counter()
    last_nft_op = None
    for op in tr['ops']:
        if op['type'] == 'transaction' and op['receiver'] == src.config.name2addr['nft_contract']:
            nft_calls[op['parameters']['call']] += 1
            last_nft_op = op
    nft_calls = dict(nft_calls)

    money_delta = get_tr_money_delta(tr)
    known_money_delta = {
        src.config.addr2name[addr]: delta
        for addr, delta in money_delta.items()
        if addr in src.config.addr2name
    }

    if nft_calls == {'transfer': 1}:
        assert last_nft_op['parameters']['call'] == 'transfer'
        transfer = last_nft_op['parameters']['value']['transfer']
        assert len(transfer) == 1
        sender = transfer[0]['from_']

        # when the first transfer between users (with non-zero price) will happen,
        # this assert will fail
        assert sender == src.config.name2addr['art_house_contract']
        assert money_delta[src.config.name2addr['art_house_contract']] < 1e-10

        assert len(transfer[0]['txs']) == 1
        receiver = transfer[0]['txs'][0]['to_']

        token_id = int(transfer[0]['txs'][0]['token_id'])
        token_count = int(transfer[0]['txs'][0]['amount'])
        comission_wallet_income = money_delta[src.config.name2addr['comission_wallet']]

        beneficiaries = {}
        payers = {}
        for addr, delta in money_delta.items():
            if addr in [
                src.config.name2addr['art_house_contract'],
                src.config.name2addr['comission_wallet'],
            ]:
                continue
            if delta > 0:
                beneficiaries[addr] = delta
            elif delta < 0:
                payers[addr] = delta

        if receiver == src.config.name2addr['comission_wallet']:
            assert len(payers) == 0
            assert len(beneficiaries) == 1
            payer = src.config.name2addr['comission_wallet']
            assert comission_wallet_income < 0
            price = abs(comission_wallet_income) / (1.0 - 0.025)
            comission = price * 0.025

        elif len(beneficiaries) == 0:
            assert len(payers) == 1
            payer = list(payers)[0]
            assert money_delta[payer] == -comission_wallet_income
            assert comission_wallet_income > 0
            price = abs(comission_wallet_income)
            beneficiary = src.config.name2addr['comission_wallet']
            comission = price * 0.025

        else:
            assert len(payers) == 1
            assert len(beneficiaries) == 1
            assert comission_wallet_income > 0
            comission = comission_wallet_income
            payer = list(payers)[0]
            price = -money_delta[payer]
            beneficiary = list(beneficiaries)[0]

        assert type(payer) is str
        assert type(beneficiary) is str
        assert price > 0
        assert comission > 0
        assert abs(comission - price * 0.025) < 1e-6

        money_state.apply_swap_sell(
            row_id=last_nft_op['row_id'],
            token_id=token_id,
            token_count=token_count,
            payer=payer,
            beneficiary=beneficiary,
            price=price,
            comission=comission,
        )
        continue

    assert nft_calls == {}
    known_money_addrs = set(known_money_delta.keys())

    assert 'comission_wallet' in known_money_addrs

    if 'baking_benjamins' in known_money_addrs:
        assert known_money_addrs == {'baking_benjamins', 'comission_wallet'}
        assert known_money_delta['baking_benjamins'] < 0
        assert known_money_delta['comission_wallet'] > 0
        assert known_money_delta['comission_wallet'] < -known_money_delta['baking_benjamins']
        money_state.apply_comission_wallet_baking_percent(
            row_id=tr['ops'][0]['row_id'],
            sender=src.config.name2addr['baking_benjamins'],
            volume=known_money_delta['comission_wallet'],
        )
        continue

    assert known_money_addrs == { 'comission_wallet' }
    assert known_money_delta['comission_wallet'] < 0
    other_addrs = set(money_delta.keys()) - {src.config.name2addr['comission_wallet']}
    assert len(other_addrs) == 1
    other_addr = list(other_addrs)[0]
    volume = money_delta[other_addr]
    assert volume > 0
    assert money_delta == {
        src.config.name2addr['comission_wallet']: -volume,
        other_addr: volume
    }
    money_state.apply_comission_wallet_spending(
        row_id=tr['ops'][0]['row_id'],
        receiver=other_addr,
        volume=volume,
    )

# %%
comission_wallet_initial_volume = 102.02

# %%
src.config.name2addr['comission_wallet']
# Out:
# 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw'

# %%
comission_wallet_initial_volume + money_state.balances[src.config.name2addr['comission_wallet']]
# Out:
# 1788.859149000093

# %%
comission_wallet_initial_volume + money_state.comission_wallet['comission_income'] + money_state.comission_wallet['percent_income'] - money_state.comission_wallet['spending'] - money_state.addrs[src.config.name2addr['comission_wallet']]['total_bought'] + money_state.addrs[src.config.name2addr['comission_wallet']]['total_sold']
# Out:
# 1788.8591490001595

# %% [markdown]
# ## Check comission wallet transactions

# %%
i_dianov_addr = 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii'

# %%
money_state.addrs[i_dianov_addr]
# Out:
# {'total_bought': 22.6,
#  'total_sold': 147.22499999999985,
#  'events': [{'row_id': 42597772,
#    'type': 'swap_sell',
#    'token_id': 898,
#    'token_count': 1,
#    'payer': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'beneficiary': 'tz2VN3fWzqHE44F6zedJB7UtALKEh5WhqAJJ',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42605395,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz2VN3fWzqHE44F6zedJB7UtALKEh5WhqAJJ',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42606482,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz2SV4pB3uxG7pzqw5rvZAh4agPbuYJnKxsS',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42606801,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1Ro4mBmTSx1crHwQx6B41w2oG8B82WfeGa',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42607180,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1SoKFcnJJpkihm8AEgCRGgNpefePEAnHQE',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42607468,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz2PcNnB3GS7WuMq6VUgoE2HRaLfWxPFFZfH',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42607488,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1Ry79UpM3e9sToPfxKsWnPw3Y447YEfu7E',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42607533,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1SzjK1j7YgfXatHA4WQnZodsfRbYxkRP7P',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42608398,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1V84gmD8MsmLuCfT9M1LDaTjpJb4eAejvM',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42608884,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1YjmR1StFsGGJZ3jm6YuG7B1uNP3i6Bss4',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42608974,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1hcrhwAjMMPhp4hqYGhysh1MUua5UBK22r',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42609045,
#    'type': 'swap_sell',
#    'token_id': 1085,
#    'token_count': 1,
#    'payer': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'beneficiary': 'tz2VN3fWzqHE44F6zedJB7UtALKEh5WhqAJJ',
#    'price': 10,
#    'comission': 0.25},
#   {'row_id': 42609890,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1LS9yPMo6cUQcxpeakNAJkPnAMqLrvjGCo',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42610496,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1YRG68NdqtAcsFEwTUw6FsSsiBb5kagEDo',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42613886,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1PzXjyPchzGUGH9yXLTgvyhhakFnyYDYge',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42614247,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1hhG3vN2NCoPZepvEbKHBFQ5denwNJwHXP',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42614291,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1Zba3FPSgwhJfDBjRFtYoe9Mec5nBG2bJr',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42617259,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1SHHVL22Ca2UZnUoZtgbAMAZViB3emcErA',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42619125,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1Z9s59QUmYTs4NKf48uHhcgeY5wimpFWiX',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42622663,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1Y7iKsQVTa5wJC8VxLJyB8ac3yEKu5w7HE',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42623307,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1c2iwyckUCcicx2qxqtwLEartYFEHg1pvB',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42624992,
#    'type': 'swap_sell',
#    'token_id': 1189,
#    'token_count': 1,
#    'payer': 'tz1YjmR1StFsGGJZ3jm6YuG7B1uNP3i6Bss4',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 10,
#    'comission': 0.25},
#   {'row_id': 42625276,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1SurB57FnMqL4pVjAarVD5YndMdvyBhzTD',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42626605,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz2Pkj2xWJovKKCsABjnr3NbyMVJTMBkpTvb',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42627945,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1iPwJuTUVMhid9ahKn2Yb4CVGh2PB2hhR9',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42630817,
#    'type': 'swap_sell',
#    'token_id': 1339,
#    'token_count': 1,
#    'payer': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'beneficiary': 'tz1ScnxV6dRwQ3rDM8eTs6Gn7isnHHx4bk1r',
#    'price': 5,
#    'comission': 0.125},
#   {'row_id': 42632054,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz2PBAJo8zSWvHXh7Z2VineRxPP3tn27JPQf',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42654463,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1QDunNSnWrqwCc78TqzHP86BMNXq1P7Jxb',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42655548,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz2AmQarWLeMoQVt2h9a4QYywTUtg8bH5t5B',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42660544,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1fgCrWPaMX3ADd6cPZuZYpyP2t9vSd1xem',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42660959,
#    'type': 'swap_sell',
#    'token_id': 1527,
#    'token_count': 1,
#    'payer': 'tz1Q86tz2HeTL6iwHVcYe7nGUN4zSU545nWf',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 5,
#    'comission': 0.125},
#   {'row_id': 42661457,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42664540,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1N95RVRskAmHdhvSGde9oZJi5ba3cgSoZ8',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42665133,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1UTa3LDHvb1xvfcaH5evmsVMWNXQRxrYb2',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42677967,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1P2FnGn7zWskg8ukvDxX837Ns4waun9GAY',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42678308,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1YmG6cVx9Kh2fJKGvnMWHV9QX6htQhbuYq',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42686406,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1hLFtZGZifRn4Nrczm9bBeiiyaXDNygcZ9',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42692647,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1Zgz5rgjTg5aaL4foP6tvbYt7VNnNPiYHj',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42698646,
#    'type': 'swap_sell',
#    'token_id': 1753,
#    'token_count': 1,
#    'payer': 'tz1PFocXC9HkFenCfW1ZRhb8ZtWEtj1JUfR9',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 2,
#    'comission': 0.05},
#   {'row_id': 42712428,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1dC1gNTYrpRx8wKdZFhUX7oK8h6o2j6UdV',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42718393,
#    'type': 'swap_sell',
#    'token_id': 1445,
#    'token_count': 1,
#    'payer': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'beneficiary': 'tz1Y7iKsQVTa5wJC8VxLJyB8ac3yEKu5w7HE',
#    'price': 3,
#    'comission': 0.075},
#   {'row_id': 42721387,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1KqzBPfhoTquknvyWSsHQ3PX5VDaoYMqq7',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42721507,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1VQavbLDpbtSKY5Qfs8D83YmuV5X6nUD3J',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42786872,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1ij35MEpDby7o3iHHZzewiQCTiQfJfiV4v',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42792732,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1gA2pHGJtdShZKryFy6yFRTA8D9cnS4qwS',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42802771,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1f51PdCRQT5Sywc3QpbBye1XPAup6tJCf3',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42803863,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1f51PdCRQT5Sywc3QpbBye1XPAup6tJCf3',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42804716,
#    'type': 'swap_sell',
#    'token_id': 2235,
#    'token_count': 1,
#    'payer': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'beneficiary': 'tz1UAY5RSuG6nRJhdHDVMVSg9Lt2pSZez5JR',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42818108,
#    'type': 'swap_sell',
#    'token_id': 2717,
#    'token_count': 1,
#    'payer': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'beneficiary': 'tz1TAwX56aagtoniLkZTSCAAjaMc1F8mWm9K',
#    'price': 0.1,
#    'comission': 0.0025},
#   {'row_id': 42824071,
#    'type': 'swap_sell',
#    'token_id': 2744,
#    'token_count': 1,
#    'payer': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'beneficiary': 'tz1PqCt3ACUU8DyubywKcRUc6Rbdau3MYrTF',
#    'price': 0.5,
#    'comission': 0.0125},
#   {'row_id': 42858500,
#    'type': 'swap_sell',
#    'token_id': 2974,
#    'token_count': 1,
#    'payer': 'tz1ZHas6yUhPYDwnxCYeMiUaNfh6Cxd27i1o',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 8,
#    'comission': 0.2},
#   {'row_id': 42858553,
#    'type': 'swap_sell',
#    'token_id': 2962,
#    'token_count': 1,
#    'payer': 'tz1ZHas6yUhPYDwnxCYeMiUaNfh6Cxd27i1o',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 8,
#    'comission': 0.2},
#   {'row_id': 42858645,
#    'type': 'swap_sell',
#    'token_id': 2951,
#    'token_count': 1,
#    'payer': 'tz1ZHas6yUhPYDwnxCYeMiUaNfh6Cxd27i1o',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 5,
#    'comission': 0.125},
#   {'row_id': 42858690,
#    'type': 'swap_sell',
#    'token_id': 2966,
#    'token_count': 1,
#    'payer': 'tz1ZHas6yUhPYDwnxCYeMiUaNfh6Cxd27i1o',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 8,
#    'comission': 0.2},
#   {'row_id': 42861424,
#    'type': 'swap_sell',
#    'token_id': 2951,
#    'token_count': 1,
#    'payer': 'tz1ScnxV6dRwQ3rDM8eTs6Gn7isnHHx4bk1r',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 5,
#    'comission': 0.125},
#   {'row_id': 42875401,
#    'type': 'swap_sell',
#    'token_id': 3079,
#    'token_count': 1,
#    'payer': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'beneficiary': 'tz1TS14F92TqsEVhWxGkeKq22p7HW7Kd4WXz',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42949206,
#    'type': 'swap_sell',
#    'token_id': 4120,
#    'token_count': 1,
#    'payer': 'tz1UqpNLoPRpAPKCTsgXyBRitTdpKJWEjVKT',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42954559,
#    'type': 'swap_sell',
#    'token_id': 4134,
#    'token_count': 1,
#    'payer': 'tz1L1XwcVmD2z4qPfLtBJ6RPThgAwLcXG6kW',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 42958055,
#    'type': 'swap_sell',
#    'token_id': 4134,
#    'token_count': 1,
#    'payer': 'tz1Zgz5rgjTg5aaL4foP6tvbYt7VNnNPiYHj',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43042998,
#    'type': 'swap_sell',
#    'token_id': 1519,
#    'token_count': 1,
#    'payer': 'tz1TgwVWRhbQDmqpDR67gRPGa3YjXrJdziTa',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 5,
#    'comission': 0.125},
#   {'row_id': 43065063,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1LBs6F9tZ4Qdf4vvCF9ikjeyHaQmmAW3Yu',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43071352,
#    'type': 'swap_sell',
#    'token_id': 4134,
#    'token_count': 1,
#    'payer': 'tz1XEJFTcKBmQrQHgAEsQ4UUWfk1FMnG5SeA',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43071815,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1QeWGaxvPy8Cxj8Dvm3i6xG6mwyjCpwYzu',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43250668,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1YRG68NdqtAcsFEwTUw6FsSsiBb5kagEDo',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43315660,
#    'type': 'swap_sell',
#    'token_id': 6217,
#    'token_count': 1,
#    'payer': 'tz1Zgz5rgjTg5aaL4foP6tvbYt7VNnNPiYHj',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 5,
#    'comission': 0.125},
#   {'row_id': 43464124,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1QFFvtYHPdvPC72AtsxvoeLXDUE8YutqXa',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43484196,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1f94uZ7SF2fLKnMjFzGQTbznd8qpAZ12is',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43527612,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1cALmpTf7EeeSBXHAX2rcnR4WAP8tSWkt6',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43528119,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1c2iwyckUCcicx2qxqtwLEartYFEHg1pvB',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43528527,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1Tk1MJDZ96bK85RLAqtKfnptZZyXsJ2jaq',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43528934,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1aR63j3a9igB7Je8LDf3LMJBZ2AHffNHKN',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43529230,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1YRG68NdqtAcsFEwTUw6FsSsiBb5kagEDo',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43530548,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1gi68wGST7UtzkNpnnc354mpqCcVNQVcSw',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43532531,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1fPtXpoqSDgSeHeX2q5BLg9sC3KccZ5Kd5',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43534819,
#    'type': 'swap_sell',
#    'token_id': 6079,
#    'token_count': 1,
#    'payer': 'tz1ZHas6yUhPYDwnxCYeMiUaNfh6Cxd27i1o',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 2,
#    'comission': 0.05},
#   {'row_id': 43534954,
#    'type': 'swap_sell',
#    'token_id': 1526,
#    'token_count': 1,
#    'payer': 'tz1ZHas6yUhPYDwnxCYeMiUaNfh6Cxd27i1o',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 5,
#    'comission': 0.125},
#   {'row_id': 43535364,
#    'type': 'swap_sell',
#    'token_id': 6049,
#    'token_count': 1,
#    'payer': 'tz1ZHas6yUhPYDwnxCYeMiUaNfh6Cxd27i1o',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 5,
#    'comission': 0.125},
#   {'row_id': 43540644,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1LDv2M4sza54dnay8pfcdCXGXgdtwyKUBA',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43542242,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1WqBtWEXjYPwKofxDPsf2V8Jo7dRxdKYqu',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43542314,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1NSff9qnqyV7Afa5izXD6bcWq4YNzFGgJv',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43543319,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1TeLXGCQYuJyeSJcbdynDP2nh8t1A7AocZ',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43543599,
#    'type': 'swap_sell',
#    'token_id': 8351,
#    'token_count': 1,
#    'payer': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'beneficiary': 'tz1WqBtWEXjYPwKofxDPsf2V8Jo7dRxdKYqu',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43550020,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1Xk3eXrc8xuXG9gZa32NuSHaJqfxFDToFf',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43564968,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1Scn9Ttn9AhFh5TnqFyDYD8JherrknX4rz',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43568608,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1Scn9Ttn9AhFh5TnqFyDYD8JherrknX4rz',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43573046,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1L7oVDv58oKd6dDrRAgXMhgZbJREvmrMg9',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43667726,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1bgaARyoECcMEJaRz71pD82mRQerXqxtVc',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43678407,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1Scn9Ttn9AhFh5TnqFyDYD8JherrknX4rz',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43686797,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1XzWcPJp1sNk4WWazx9yPNQwr8zk2sBL1N',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43698535,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1Rwx6G3MFW5VCeSd4bJQphXuUR3Q56omLW',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43699175,
#    'type': 'swap_sell',
#    'token_id': 4163,
#    'token_count': 1,
#    'payer': 'tz1Rwx6G3MFW5VCeSd4bJQphXuUR3Q56omLW',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 5,
#    'comission': 0.125},
#   {'row_id': 43708215,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1eky73coNLY3e8b3rzBihpkC799Db3UtKp',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43722827,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1QTqwXS91qLyc9ADG2zKAqpwHVGGPcAUqX',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43760592,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1ei4YPTbFJLUa9A3bVbocw9f2oyfg8Zy8S',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43763264,
#    'type': 'swap_sell',
#    'token_id': 8218,
#    'token_count': 1,
#    'payer': 'tz1gH5qBndFDibwQ1jyZ3QDGcm35qYD7ndru',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025},
#   {'row_id': 43797886,
#    'type': 'swap_sell',
#    'token_id': 1091,
#    'token_count': 1,
#    'payer': 'tz1cZRgLNDsYM6RnNW4XThpgX9KWr4LMpywA',
#    'beneficiary': 'tz1MwvWz611pLwYdFMZpWCEsh247MEYtm5ii',
#    'price': 1,
#    'comission': 0.025}]}

# %%
money_state.balances[i_dianov_addr]
# Out:
# 124.62499999999984

# %%
money_state_r = MoneyState()
money_state_replayer = src.contracts.state_utils.StateReplayer(money_state.log, money_state_r)

# %%
cw_balance = comission_wallet_initial_volume

first_op = None

for tr in money_trs: # src.iter_tr.iter_tr():
    for op in tr['ops']:
        if op['status'] != 'applied':
            continue
        if op['volume'] == 0:
            continue
        if first_op is None:
            first_op = op
        if op['sender'] == src.config.name2addr['comission_wallet']:
            cw_balance -= op['volume']
        if op['receiver'] == src.config.name2addr['comission_wallet']:
            cw_balance += op['volume']
    # money_state_replayer.replay_to_after_row_id(tr['ops'][-1]['row_id'])
    # print(cw_balance, comission_wallet_initial_volume + money_state_r.balances[src.config.name2addr['comission_wallet']])

cw_balance
# Out:
# 1788.8591490001104

# %%
src.config.name2addr['comission_wallet']
# Out:
# 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw'

# %%
102.043724 - 0.975
# Out:
# 101.068724

# %%
0.975 == 1.0 * (1.0 - 0.025)
# Out:
# True

# %%
get_tr_money_delta(tr)
# Out:
# {'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': -0.975,
#  'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0.0,
#  'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z': 0.975}

# %%
tr['ops'][-1]['row_id']
# Out:
# 43940499

# %%
first_op['time']
# Out:
# '2021-02-28T14:42:45Z'

# %%
def get_tr_money_delta(tr):
    res = {}
    for op in tr['ops']:
        if op['volume'] == 0:
            continue
        sender, receiver = op['sender'], op['receiver']
        res[sender] = res.get(sender, 0) - op['volume']
        res[receiver] = res.get(receiver, 0) + op['volume']
    return res


def get_addr_signature(addr):
    return src.config.addr2name.get(addr, '*')


def get_op_signature(op):
    if op['status'] != 'applied':
        return op['status']
    if op['type'] != 'transaction':
        return op['type']
    call = op.get('parameters', {'call': ''})['call']
    if op['volume'] > 0:
        return (
            call,
            get_addr_signature(op['sender']) + ' > ' + get_addr_signature(op['receiver']),
        )
    return call


def get_tr_signature(tr):
    ext_count = 0
    res = tuple()
    has_any_applied = False
    for op in tr['ops']:
        if op['type'] == 'reveal':
            continue
        if op['status'] == 'applied':
            has_any_applied = True
        if op['sender'] not in src.config.addr2name and op.get('receiver') not in src.config.addr2name:
            ext_count += 1
        else:
            res += (get_op_signature(op),)
    if not has_any_applied:
        return tr['ops'][0]['status']
    res = (ext_count > 0,) + res
    return res

# %%
nft_state_replayer.replay_to_end()
ah_state_replayer.replay_to_end()

# %%
import requests

r = requests.get('https://api.tzstats.com/explorer/op/op8eBZNRQY8SFXZJmYpHczAdSGhzPjpFBRr3kUxupYegfAPRuzu')
r.text
# Out:
# '[{"row_id":43782809,"hash":"op8eBZNRQY8SFXZJmYpHczAdSGhzPjpFBRr3kUxupYegfAPRuzu","type":"transaction","block":"BKsCu8zwXR3tkM5BcvvJWkENFArGdHfTzXCMfzR3JbNyBLxVmfA","time":"2021-03-22T20:44:38Z","height":1396278,"cycle":340,"counter":11763276,"op_l":3,"op_p":4,"op_c":0,"op_i":0,"status":"applied","is_success":true,"is_contract":true,"gas_limit":93655,"gas_used":68475,"gas_price":0.14284,"storage_limit":209,"storage_size":1831924,"storage_paid":0,"volume":0,"fee":0.009781,"has_data":true,"days_destroyed":0,"parameters":{"entrypoint":"mint_OBJKT","call":"mint_OBJKT","branch":"RLR","id":4,"value":{"address":"tz1bJwj5KBMc3UFk3ijykA9c1sGDmw4FEy24","amount":"100","metadata":"ipfs://QmaHsLuyrxex9CusGS29i4taHA6AWPvfircvMQbMhFBboy","royalties":"100"}},"storage":{"value":{"curate":"KT1TybhR7XraG75JFYKSrh7KnxukMBT5dor6","genesis":"2021-04-15T02:09:41Z","hdao":"KT1AFA2mwNUMNd4SsujE1YYp29vd8BZejyKW","locked":"true","manager":"tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw","metadata":"521","objkt":"KT1RJ6PbjHpwc3M5rw5s2Nbmefwbuwbdxton","objkt_id":"10709","royalties":"522","size":"0","swap_id":"10743","swaps":"523"}},"big_map_diff":[{"key":"10708","key_hash":"exprurBQ4j4fzAAhDhsETuRzjuGWPx3P9ssMmjNMikFLZ8R66wk9DH","key_binary":"10708","value":{"issuer":"tz1bJwj5KBMc3UFk3ijykA9c1sGDmw4FEy24","royalties":"100"},"action":"update"}],"sender":"tz1bJwj5KBMc3UFk3ijykA9c1sGDmw4FEy24","receiver":"KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9","entrypoint_id":4},{"row_id":43782810,"hash":"op8eBZNRQY8SFXZJmYpHczAdSGhzPjpFBRr3kUxupYegfAPRuzu","type":"transaction","block":"BKsCu8zwXR3tkM5BcvvJWkENFArGdHfTzXCMfzR3JbNyBLxVmfA","time":"2021-03-22T20:44:38Z","height":1396278,"cycle":340,"counter":5,"op_l":3,"op_p":4,"op_c":0,"op_i":0,"status":"applied","is_success":true,"is_contract":true,"gas_limit":0,"gas_used":25080,"gas_price":0,"storage_limit":0,"storage_size":3799561,"storage_paid":209,"volume":0,"fee":0,"burned":0.05225,"is_internal":true,"has_data":true,"days_destroyed":0,"parameters":{"entrypoint":"mint","call":"mint","branch":"LRL","id":2,"value":{"address":"tz1bJwj5KBMc3UFk3ijykA9c1sGDmw4FEy24","amount":"100","token_id":"10708","token_info":{"0@bytes":"ipfs://QmaHsLuyrxex9CusGS29i4taHA6AWPvfircvMQbMhFBboy"}}},"storage":{"value":{"administrator":"KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9","all_tokens":"10709","ledger":"511","metadata":"512","operators":"513","paused":"false","token_metadata":"514"}},"big_map_diff":[{"key":"10708","key_hash":"exprv2kyjRNoAuBTtXFY8kuDT1WjrD5HzfwZVidndfvEi4wFNng3us","key_binary":"10708","value":{"token_id":"10708","token_info":{"0@bytes":"ipfs://QmaHsLuyrxex9CusGS29i4taHA6AWPvfircvMQbMhFBboy"}},"action":"update"},{"key":{"0@address":"tz1bJwj5KBMc3UFk3ijykA9c1sGDmw4FEy24","1@nat":"10708"},"key_hash":"exprv2kyjRNoAuBTtXFY8kuDT1WjrD5HzfwZVidndfvEi4wFNng3us","key_binary":"07070a000000160000abe5f6b05398b5c1b0a96f13541b126a34c6e5740094a701","value":"100","action":"update"}],"sender":"KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9","receiver":"KT1RJ6PbjHpwc3M5rw5s2Nbmefwbuwbdxton","creator":"tz1bJwj5KBMc3UFk3ijykA9c1sGDmw4FEy24","entrypoint_id":2}]\n'

# %%
nft_state_replayer.replay_to_end()

# %%
nft_state.tokens
# Out:
# {152: {'creator': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://Qma11k6ahPRXGVV7RgHNuLuwB9PqQB2MVJUtNNXJ7dQeAr',
#   'mint_row_id': 42212376,
#   'own_counts': {'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 1,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0},
#   'transfers': [{'from': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42467796},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'count': 1,
#     'row_id': 42468333}]},
#  153: {'creator': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#   'mint_count': 2,
#   'info_ipfs': 'ipfs://QmeaqRBUiw4cJiNKEcW2noc7egLd5GgBqLcHHqUhauJAHN',
#   'mint_row_id': 42220283,
#   'own_counts': {'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 2},
#   'transfers': []},
#  154: {'creator': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#   'mint_count': 2,
#   'info_ipfs': 'ipfs://QmUxvVm8vxZ8zzxD8zU4ZCsKUPHc888ztrkaFcGasEKzbp',
#   'mint_row_id': 42220469,
#   'own_counts': {'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 1,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1Zz4MmtM6mpzh5XWiAEXGeP9iWsT7PSmzg': 1},
#   'transfers': [{'from': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42226230},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Zz4MmtM6mpzh5XWiAEXGeP9iWsT7PSmzg',
#     'count': 1,
#     'row_id': 42226323}]},
#  155: {'creator': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmPdZuUXnTJSVgZNYYWgfkcgYrd3kUjmJV6Ba5FyMuyM2d',
#   'mint_row_id': 42227960,
#   'own_counts': {'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 5},
#   'transfers': [{'from': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42231509}]},
#  156: {'creator': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmeDfhJZn7wTh1h5UNUJKM5CcD8LGTpR5RaT3D35NZv35Q',
#   'mint_row_id': 42228946,
#   'own_counts': {'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 3,
#    'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp': 1,
#    'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z': 1},
#   'transfers': [{'from': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42231312},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp',
#     'count': 1,
#     'row_id': 42234788},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z',
#     'count': 1,
#     'row_id': 42236213}]},
#  157: {'creator': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#   'mint_count': 100,
#   'info_ipfs': 'ipfs://QmUKCfBnpN4CurChDS96wMcQ1akUJXiKtkZtHgHmieZUyL',
#   'mint_row_id': 42229582,
#   'own_counts': {'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq': 0,
#    'tz1dfERyYcVRPG4WkZPf8k9TeRvc6i2gqBPx': 100},
#   'transfers': [{'from': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#     'to': 'tz1dfERyYcVRPG4WkZPf8k9TeRvc6i2gqBPx',
#     'count': 100,
#     'row_id': 42230318}]},
#  158: {'creator': 'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z',
#   'mint_count': 50,
#   'info_ipfs': 'ipfs://QmXtWB7WJE1NHQDsW7odJM6FmpJT1bawQd6gC6fJav94MP',
#   'mint_row_id': 42229959,
#   'own_counts': {'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z': 40,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 3,
#    'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 0,
#    'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE': 1,
#    'tz1Zz4MmtM6mpzh5XWiAEXGeP9iWsT7PSmzg': 1,
#    'tz1YkVzUhf7YB9Dpfac1JCbqpxkxXrotQJeM': 1,
#    'tz1dUexxVsqFV4NX8fdeYmfkn2arjUBDV4r2': 1,
#    'tz1PLPNFCvxmDNh9T9cACkKQUH243D7fY6C4': 2,
#    'tz1hcKhpB82SShLcFYM8GKMu3aZGzU5NM9zi': 1},
#   'transfers': [{'from': 'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 10,
#     'row_id': 42230104},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'count': 1,
#     'row_id': 42230465},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'count': 1,
#     'row_id': 42243716},
#    {'from': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'to': 'tz1Zz4MmtM6mpzh5XWiAEXGeP9iWsT7PSmzg',
#     'count': 1,
#     'row_id': 42353485},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1YkVzUhf7YB9Dpfac1JCbqpxkxXrotQJeM',
#     'count': 1,
#     'row_id': 42430466},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dUexxVsqFV4NX8fdeYmfkn2arjUBDV4r2',
#     'count': 1,
#     'row_id': 42860299},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1PLPNFCvxmDNh9T9cACkKQUH243D7fY6C4',
#     'count': 1,
#     'row_id': 43463548},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1PLPNFCvxmDNh9T9cACkKQUH243D7fY6C4',
#     'count': 1,
#     'row_id': 43463581},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hcKhpB82SShLcFYM8GKMu3aZGzU5NM9zi',
#     'count': 1,
#     'row_id': 43715647}]},
#  159: {'creator': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#   'mint_count': 100,
#   'info_ipfs': 'ipfs://Qmbs74bRe9x2x7tL87z1ox7QrANDUW4kJpXVBXxNp8YQzg',
#   'mint_row_id': 42230107,
#   'own_counts': {'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 0,
#    'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z': 1,
#    'tz1QRm2TJKnarZ9tbL5CNjN4Ltq9pJtytuk7': 1,
#    'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z': 1,
#    'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx': 6,
#    'tz1eee5rapGDbq2bcZYTQwNbrkB4jVSQSSHx': 1,
#    'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN': 66,
#    'tz2MkhsWEcgCsaXJgrXAiYJE8y72qZT3xfHe': 1,
#    'tz1Yoh9NmyM3FeG37iVQJs75nSW9REcuaAtR': 1,
#    'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK': 1,
#    'tz1cW7NSbACRKyzYR8pgCvTtAH8qEnv6AX1J': 0,
#    'tz1SBxNvpDFC4bjW23CtQfVLqN5cBATVf68B': 1,
#    'tz1PAoigCex9CcckWMimaWFAdKmN1AfwJ2Xa': 1,
#    'tz1Rb2U9TbEkYVQM412wBzBbMbnqX2r4CTXs': 1,
#    'tz1fKTtok4A2DR76HVbj9RZuCczTyt1HgYEo': 1,
#    'tz1MkstMV99nRE1PdAatkpwUevtDf5KkJn4Z': 1,
#    'tz1NkFRjmkqqcGkAhqe78fdgemDNKXvL7Bod': 1,
#    'tz29us8pNRFUbsMMuQjBGZyWndBGTFtGdLBW': 1,
#    'tz1WntXgznbivRjyhE7Y5jEzoebAhMPB2iJa': 7,
#    'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3': 1,
#    'tz2P5LDf8pQRfwCCvx2VmRXnwzeqqrbjKC8U': 0,
#    'tz2FRZpH4XSqCoyHv7cLwp8wvBBBZ6Z1LCeW': 1,
#    'tz2UD7tXJyBrfDBHnFzhnaeL8ZGHxcDZuDa3': 1,
#    'tz1Zz4MmtM6mpzh5XWiAEXGeP9iWsT7PSmzg': 1,
#    'tz2GK2n3iUmekDjAipmw8qcAL3k6Y1iwKErA': 1,
#    'tz2Gr4iaocKZVGC92a7MSaMi8aY8Q68Zwn2B': 0,
#    'tz1aZsKPTRdkm9vaQhWv9Mz8ZbwxSHmf7t9T': 1,
#    'tz1dRzFntQFNYEq7Pg3UL9VZM7P5AHJ9weZB': 1},
#   'transfers': [{'from': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 100,
#     'row_id': 42231254},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'count': 1,
#     'row_id': 42231351},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z',
#     'count': 1,
#     'row_id': 42234186},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1QRm2TJKnarZ9tbL5CNjN4Ltq9pJtytuk7',
#     'count': 1,
#     'row_id': 42234752},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#     'count': 1,
#     'row_id': 42235300},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'count': 1,
#     'row_id': 42237152},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'count': 1,
#     'row_id': 42238667},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'count': 1,
#     'row_id': 42238865},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'count': 1,
#     'row_id': 42239436},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1eee5rapGDbq2bcZYTQwNbrkB4jVSQSSHx',
#     'count': 1,
#     'row_id': 42242381},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42243805},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2MkhsWEcgCsaXJgrXAiYJE8y72qZT3xfHe',
#     'count': 1,
#     'row_id': 42244286},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'count': 1,
#     'row_id': 42244735},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Yoh9NmyM3FeG37iVQJs75nSW9REcuaAtR',
#     'count': 1,
#     'row_id': 42245598},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#     'count': 1,
#     'row_id': 42246364},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246404},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246434},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246480},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1cW7NSbACRKyzYR8pgCvTtAH8qEnv6AX1J',
#     'count': 1,
#     'row_id': 42246487},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246512},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246548},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246622},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246659},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246775},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246812},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246882},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42246986},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1SBxNvpDFC4bjW23CtQfVLqN5cBATVf68B',
#     'count': 1,
#     'row_id': 42247015},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247082},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247124},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247158},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247194},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247237},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247284},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247318},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247348},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247384},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247422},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247464},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247617},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42247671},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42248100},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42248130},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42248159},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42248262},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42248293},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1PAoigCex9CcckWMimaWFAdKmN1AfwJ2Xa',
#     'count': 1,
#     'row_id': 42250511},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Rb2U9TbEkYVQM412wBzBbMbnqX2r4CTXs',
#     'count': 1,
#     'row_id': 42259283},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1fKTtok4A2DR76HVbj9RZuCczTyt1HgYEo',
#     'count': 1,
#     'row_id': 42259508},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1MkstMV99nRE1PdAatkpwUevtDf5KkJn4Z',
#     'count': 1,
#     'row_id': 42259510},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1NkFRjmkqqcGkAhqe78fdgemDNKXvL7Bod',
#     'count': 1,
#     'row_id': 42262099},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz29us8pNRFUbsMMuQjBGZyWndBGTFtGdLBW',
#     'count': 1,
#     'row_id': 42269080},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1WntXgznbivRjyhE7Y5jEzoebAhMPB2iJa',
#     'count': 1,
#     'row_id': 42285271},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292097},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292126},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292194},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292231},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292268},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292350},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292393},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292463},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292538},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292604},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292644},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292679},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292751},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292777},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292831},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292864},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42292961},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293007},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293036},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293076},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293110},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293144},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293175},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293247},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293280},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293386},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293451},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293477},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293555},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42293653},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#     'count': 1,
#     'row_id': 42293898},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1WntXgznbivRjyhE7Y5jEzoebAhMPB2iJa',
#     'count': 1,
#     'row_id': 42296883},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1WntXgznbivRjyhE7Y5jEzoebAhMPB2iJa',
#     'count': 1,
#     'row_id': 42297261},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1WntXgznbivRjyhE7Y5jEzoebAhMPB2iJa',
#     'count': 1,
#     'row_id': 42297403},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1WntXgznbivRjyhE7Y5jEzoebAhMPB2iJa',
#     'count': 1,
#     'row_id': 42297440},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1WntXgznbivRjyhE7Y5jEzoebAhMPB2iJa',
#     'count': 1,
#     'row_id': 42297575},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1WntXgznbivRjyhE7Y5jEzoebAhMPB2iJa',
#     'count': 1,
#     'row_id': 42297808},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2P5LDf8pQRfwCCvx2VmRXnwzeqqrbjKC8U',
#     'count': 1,
#     'row_id': 42298474},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2FRZpH4XSqCoyHv7cLwp8wvBBBZ6Z1LCeW',
#     'count': 1,
#     'row_id': 42302759},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2FRZpH4XSqCoyHv7cLwp8wvBBBZ6Z1LCeW',
#     'count': 1,
#     'row_id': 42303171},
#    {'from': 'tz2FRZpH4XSqCoyHv7cLwp8wvBBBZ6Z1LCeW',
#     'to': 'tz2UD7tXJyBrfDBHnFzhnaeL8ZGHxcDZuDa3',
#     'count': 1,
#     'row_id': 42303832},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'count': 1,
#     'row_id': 42304133},
#    {'from': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'to': 'tz1Zz4MmtM6mpzh5XWiAEXGeP9iWsT7PSmzg',
#     'count': 1,
#     'row_id': 42353420},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2FRZpH4XSqCoyHv7cLwp8wvBBBZ6Z1LCeW',
#     'count': 1,
#     'row_id': 42356755},
#    {'from': 'tz2FRZpH4XSqCoyHv7cLwp8wvBBBZ6Z1LCeW',
#     'to': 'tz2GK2n3iUmekDjAipmw8qcAL3k6Y1iwKErA',
#     'count': 1,
#     'row_id': 42357063},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42385269},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42385345},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42385382},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42385455},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42385523},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dxePVAGzSY7tvDX7U2sEfCu8Dk2YRGhpN',
#     'count': 1,
#     'row_id': 42385637},
#    {'from': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#     'to': 'tz2Gr4iaocKZVGC92a7MSaMi8aY8Q68Zwn2B',
#     'count': 1,
#     'row_id': 42443645},
#    {'from': 'tz2Gr4iaocKZVGC92a7MSaMi8aY8Q68Zwn2B',
#     'to': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#     'count': 1,
#     'row_id': 42443813},
#    {'from': 'tz1cW7NSbACRKyzYR8pgCvTtAH8qEnv6AX1J',
#     'to': 'tz1aZsKPTRdkm9vaQhWv9Mz8ZbwxSHmf7t9T',
#     'count': 1,
#     'row_id': 42919097},
#    {'from': 'tz2P5LDf8pQRfwCCvx2VmRXnwzeqqrbjKC8U',
#     'to': 'tz1dRzFntQFNYEq7Pg3UL9VZM7P5AHJ9weZB',
#     'count': 1,
#     'row_id': 43027719}]},
#  160: {'creator': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#   'mint_count': 20,
#   'info_ipfs': 'ipfs://QmUkzp6LF1YnrfxWx4YHLhsgbMorKXphZ7tywK8ANVWgEc',
#   'mint_row_id': 42231798,
#   'own_counts': {'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 15,
#    'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z': 1,
#    'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp': 1,
#    'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx': 1,
#    'tz1XwzjNxkVwQZAqaxsvYqCKY1VsciV3izQt': 1,
#    'tz1gLNb49fErXUiYdreLAAV6twp4v3Lm8V4H': 1},
#   'transfers': [{'from': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 20,
#     'row_id': 42232020},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z',
#     'count': 1,
#     'row_id': 42232139},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp',
#     'count': 1,
#     'row_id': 42232181},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'count': 1,
#     'row_id': 42238251},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1XwzjNxkVwQZAqaxsvYqCKY1VsciV3izQt',
#     'count': 1,
#     'row_id': 42863210},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1gLNb49fErXUiYdreLAAV6twp4v3Lm8V4H',
#     'count': 1,
#     'row_id': 43700152}]},
#  161: {'creator': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#   'mint_count': 7,
#   'info_ipfs': 'ipfs://QmbqmS4dnZBXRhPgFXRsMJYL22xxu7pJwwcZW749BnVfsc',
#   'mint_row_id': 42232282,
#   'own_counts': {'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 6,
#    'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx': 1},
#   'transfers': [{'from': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 7,
#     'row_id': 42232458},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'count': 1,
#     'row_id': 42238280}]},
#  162: {'creator': 'tz1hkNPg5jQ66pJpZH2boiF5AnbAcd1dt5KS',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmcgzCA5VXxDET1cg4AQpeDEnFt52ge6XwLERJREr27E7a',
#   'mint_row_id': 42232425,
#   'own_counts': {'tz1hkNPg5jQ66pJpZH2boiF5AnbAcd1dt5KS': 1},
#   'transfers': []},
#  163: {'creator': 'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmQaujhaKkJQWi22PWmSaL6UCQqZnbAMYYV8paLVBPjurG',
#   'mint_row_id': 42232460,
#   'own_counts': {'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1N33TtiYBQ67sw32rhCsMSVpZkrSHWe9aq': 1},
#   'transfers': [{'from': 'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42233476},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1N33TtiYBQ67sw32rhCsMSVpZkrSHWe9aq',
#     'count': 1,
#     'row_id': 42234079}]},
#  164: {'creator': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#   'mint_count': 2,
#   'info_ipfs': 'ipfs://QmX5NhtfSxfppecT8CUpabF4LRgpdTzJNTpbLdEjGjHPuy',
#   'mint_row_id': 42232562,
#   'own_counts': {'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx': 1,
#    'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 1},
#   'transfers': [{'from': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42232661},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'count': 1,
#     'row_id': 42238422},
#    {'from': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#     'to': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'count': 1,
#     'row_id': 42474079}]},
#  165: {'creator': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#   'mint_count': 3,
#   'info_ipfs': 'ipfs://QmTQdUJFn1yyRDcfZZVhUzbV8ucMEekihj42T7Pgua8SLe',
#   'mint_row_id': 42234963,
#   'own_counts': {'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 3},
#   'transfers': [{'from': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 2,
#     'row_id': 42235245},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#     'count': 2,
#     'row_id': 43560075},
#    {'from': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 3,
#     'row_id': 43560778}]},
#  166: {'creator': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#   'mint_count': 3,
#   'info_ipfs': 'ipfs://QmcsauWyERmrm3bvPC9dXfhCLWXjSTqGPh8WUdMRjECJGd',
#   'mint_row_id': 42235683,
#   'own_counts': {'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 3},
#   'transfers': [{'from': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 2,
#     'row_id': 42235747},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#     'count': 2,
#     'row_id': 43560042},
#    {'from': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 3,
#     'row_id': 43560417}]},
#  167: {'creator': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#   'mint_count': 3,
#   'info_ipfs': 'ipfs://QmWgwgXM6aGQbpft1PgGoq9h1edmyKxzxW45LL7a7wvNTn',
#   'mint_row_id': 42235827,
#   'own_counts': {'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1,
#    'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 1,
#    'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq': 1},
#   'transfers': [{'from': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 2,
#     'row_id': 42235891},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'count': 1,
#     'row_id': 42237188},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#     'count': 1,
#     'row_id': 42254635},
#    {'from': 'tz1U2wsJgebEvS6CZYXn1mjErRU5mSZ2ZS1Z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 43559670}]},
#  168: {'creator': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#   'mint_count': 3,
#   'info_ipfs': 'ipfs://QmXhQmzRKjMZabEnkjZgkvaxPCR223j4yp7mn1HvvmCAPS',
#   'mint_row_id': 42235855,
#   'own_counts': {'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 1,
#    'tz1XaLRi6i8qNDa4KyNjQcxFvFDDs8xi7nr1': 2},
#   'transfers': [{'from': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 3,
#     'row_id': 42236040},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#     'count': 1,
#     'row_id': 42236353},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1XaLRi6i8qNDa4KyNjQcxFvFDDs8xi7nr1',
#     'count': 1,
#     'row_id': 42236573},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1XaLRi6i8qNDa4KyNjQcxFvFDDs8xi7nr1',
#     'count': 1,
#     'row_id': 42236678}]},
#  169: {'creator': 'tz1bhMc5uPJynkrHpw7pAiBt6YMhQktn7owF',
#   'mint_count': 21,
#   'info_ipfs': 'ipfs://Qmee1zTufg9K4GBJq3FTbBi5G3fPrqdhTW3Ms53WmyKLxK',
#   'mint_row_id': 42236671,
#   'own_counts': {'tz1bhMc5uPJynkrHpw7pAiBt6YMhQktn7owF': 18,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1XYh8aN8MdCGKKhKgKwuT1duedWn22hqBt': 1,
#    'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE': 1,
#    'tz1eK6niFEPoaa3EfBfzLLXV2A6KVBma3YNs': 1},
#   'transfers': [{'from': 'tz1bhMc5uPJynkrHpw7pAiBt6YMhQktn7owF',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 20,
#     'row_id': 42237048},
#    {'from': 'tz1bhMc5uPJynkrHpw7pAiBt6YMhQktn7owF',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42237080},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1XYh8aN8MdCGKKhKgKwuT1duedWn22hqBt',
#     'count': 1,
#     'row_id': 42237899},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'count': 1,
#     'row_id': 42243770},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1eK6niFEPoaa3EfBfzLLXV2A6KVBma3YNs',
#     'count': 1,
#     'row_id': 42289125},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1bhMc5uPJynkrHpw7pAiBt6YMhQktn7owF',
#     'count': 18,
#     'row_id': 42470241}]},
#  170: {'creator': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmcHavuRcaLFw1Lv1jYZNbxyYdWG7F3XkN9NbR7R4bAdWL',
#   'mint_row_id': 42238630,
#   'own_counts': {'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1burnburnburnburnburnburnburjAYjjX': 5},
#   'transfers': [{'from': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42238960},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#     'count': 5,
#     'row_id': 42782969},
#    {'from': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#     'to': 'tz1burnburnburnburnburnburnburjAYjjX',
#     'count': 5,
#     'row_id': 42998412}]},
#  171: {'creator': 'tz2BY6RzeE9AWpjKydQnpE7wp3dtCMogU11D',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://Qmaeu8thiGALzor6DgJtSE67GRGQaMTYeGvKYJ2RWut3nC',
#   'mint_row_id': 42238900,
#   'own_counts': {'tz2BY6RzeE9AWpjKydQnpE7wp3dtCMogU11D': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 2,
#    'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp': 1,
#    'tz1L7oVDv58oKd6dDrRAgXMhgZbJREvmrMg9': 1,
#    'tz1hcKhpB82SShLcFYM8GKMu3aZGzU5NM9zi': 1},
#   'transfers': [{'from': 'tz2BY6RzeE9AWpjKydQnpE7wp3dtCMogU11D',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42239202},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp',
#     'count': 1,
#     'row_id': 42239621},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1L7oVDv58oKd6dDrRAgXMhgZbJREvmrMg9',
#     'count': 1,
#     'row_id': 43549789},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hcKhpB82SShLcFYM8GKMu3aZGzU5NM9zi',
#     'count': 1,
#     'row_id': 43716677}]},
#  172: {'creator': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmRBxStHVvD7ujUYpAAjH7QDYRmq4B1qp52G2ovNiJWHRs',
#   'mint_row_id': 42239230,
#   'own_counts': {'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE': 1},
#   'transfers': [{'from': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42239933},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'count': 1,
#     'row_id': 42243676}]},
#  173: {'creator': 'tz2BY6RzeE9AWpjKydQnpE7wp3dtCMogU11D',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmRML8ARSZ6BBwnsqWPPTFenVUmtuvX4oEaqFTsbUQ8P4G',
#   'mint_row_id': 42239272,
#   'own_counts': {'tz2BY6RzeE9AWpjKydQnpE7wp3dtCMogU11D': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 4,
#    'tz1hUfjPUtaBMJnC9QBpPK64Mj9S4PSTEfkH': 1},
#   'transfers': [{'from': 'tz2BY6RzeE9AWpjKydQnpE7wp3dtCMogU11D',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42239378},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hUfjPUtaBMJnC9QBpPK64Mj9S4PSTEfkH',
#     'count': 1,
#     'row_id': 43713940}]},
#  174: {'creator': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmYePvDFKR85koP6pphniUC3akbHjGjzqm8EqNLYccrVZo',
#   'mint_row_id': 42239614,
#   'own_counts': {'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK': 1},
#   'transfers': []},
#  175: {'creator': 'tz1cUxXMjVeGYThU7JhwN1Z4pxneftxgAkTV',
#   'mint_count': 3,
#   'info_ipfs': 'ipfs://QmUpRqtAbmt6t5h32GwKvGVgr8C7Q5vP6GzxmxCJcXkLPP',
#   'mint_row_id': 42240233,
#   'own_counts': {'tz1cUxXMjVeGYThU7JhwN1Z4pxneftxgAkTV': 3},
#   'transfers': []},
#  176: {'creator': 'tz1dPPVGVRxY45ZvnRMU3vebaBVMuhPq5bxh',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmdDRFG7xPgtvW77h8YQTZzuRHCKCxGD71pLswPMyoVMTQ',
#   'mint_row_id': 42240370,
#   'own_counts': {'tz1dPPVGVRxY45ZvnRMU3vebaBVMuhPq5bxh': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz2VQ8aVk3t1wRvk1cfactur8LkMf1Ts3x4R': 1},
#   'transfers': [{'from': 'tz1dPPVGVRxY45ZvnRMU3vebaBVMuhPq5bxh',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42472051},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2VQ8aVk3t1wRvk1cfactur8LkMf1Ts3x4R',
#     'count': 1,
#     'row_id': 42514530}]},
#  177: {'creator': 'tz1LN3wPFYuS5fCnodwxT94xVFLPtcFHvcHk',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmczdMQXPp3tcCQRSoAYcNiJTFHZVj8fvTGSFNtwmvn8jB',
#   'mint_row_id': 42240477,
#   'own_counts': {'tz1LN3wPFYuS5fCnodwxT94xVFLPtcFHvcHk': 1},
#   'transfers': []},
#  178: {'creator': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmQKqn38WaDcPKhueeCymyLmYbXSd1d2HkmJWdoyMctoiz',
#   'mint_row_id': 42240479,
#   'own_counts': {'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 5},
#   'transfers': [{'from': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42240572}]},
#  179: {'creator': 'tz1S2YCqqbddiWtFeiRXLUKcdAw5AXc66w8p',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmWHDsXG849ZRH21Fe6cxuiq1yxKwtN6KuPUrpd4vUzynK',
#   'mint_row_id': 42240512,
#   'own_counts': {'tz1S2YCqqbddiWtFeiRXLUKcdAw5AXc66w8p': 1},
#   'transfers': []},
#  180: {'creator': 'tz1a92ZVmHDSqZ2dYbcrTZG9baK7bXSMRazZ',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmUtyhfxTLE9CcYevsamQG7aBBJSASzytYs6ChaH1eRXoA',
#   'mint_row_id': 42241001,
#   'own_counts': {'tz1a92ZVmHDSqZ2dYbcrTZG9baK7bXSMRazZ': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz1a92ZVmHDSqZ2dYbcrTZG9baK7bXSMRazZ',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42241176}]},
#  181: {'creator': 'tz1codeYURj5z49HKX9zmLHms2vJN2qDjrtt',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmPgq1bsfroJ6b22vvtio2xrdoqBXBJFyPYv7y7oBsPupo',
#   'mint_row_id': 42241561,
#   'own_counts': {'tz1codeYURj5z49HKX9zmLHms2vJN2qDjrtt': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 10},
#   'transfers': [{'from': 'tz1codeYURj5z49HKX9zmLHms2vJN2qDjrtt',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42243901},
#    {'from': 'tz1codeYURj5z49HKX9zmLHms2vJN2qDjrtt',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 9,
#     'row_id': 42295073}]},
#  182: {'creator': 'tz1N49xt8AxtPDyD2ugB6n64XfEzgYf73Pie',
#   'mint_count': 25,
#   'info_ipfs': 'ipfs://QmTA9i3awYYeSFuEzoH5vm5nH8SWGczG6ZTYcpARNuehP7',
#   'mint_row_id': 42241971,
#   'own_counts': {'tz1N49xt8AxtPDyD2ugB6n64XfEzgYf73Pie': 20,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 5},
#   'transfers': [{'from': 'tz1N49xt8AxtPDyD2ugB6n64XfEzgYf73Pie',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 2,
#     'row_id': 42244857},
#    {'from': 'tz1N49xt8AxtPDyD2ugB6n64XfEzgYf73Pie',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42244985},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1N49xt8AxtPDyD2ugB6n64XfEzgYf73Pie',
#     'count': 2,
#     'row_id': 43136369}]},
#  183: {'creator': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmUUSLAUPbbubygXrgHFpRJc73NrcGtAeFgJVvrHHDy2Mw',
#   'mint_row_id': 42243046,
#   'own_counts': {'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 1},
#   'transfers': []},
#  184: {'creator': 'tz1S4Sp3WtEz3MfdBjiaRWEAG3ZDSngAR5L6',
#   'mint_count': 100,
#   'info_ipfs': 'ipfs://QmSjJASSgnnSr9HxRZmtjydaGjbQLLB2JkVLYGq3675rHF',
#   'mint_row_id': 42243609,
#   'own_counts': {'tz1S4Sp3WtEz3MfdBjiaRWEAG3ZDSngAR5L6': 98,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 2},
#   'transfers': [{'from': 'tz1S4Sp3WtEz3MfdBjiaRWEAG3ZDSngAR5L6',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 2,
#     'row_id': 42244888}]},
#  185: {'creator': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmU2HZgnTbUmZ9aomqDUNHDTJQYdTS5VtJ2jHiUhsE8Q2S',
#   'mint_row_id': 42243670,
#   'own_counts': {'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42243803}]},
#  186: {'creator': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmV6KzahxoqmhxNVgaBPkyqN8WrnfAYfedbffW7Z54h4mG',
#   'mint_row_id': 42243871,
#   'own_counts': {'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE': 5,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0},
#   'transfers': [{'from': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42243944},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'count': 5,
#     'row_id': 42804901}]},
#  187: {'creator': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#   'mint_count': 3,
#   'info_ipfs': 'ipfs://QmbUx7rzPxE9eWSceq9UZ38nLjftwXVz2W21tkQbqLzHYu',
#   'mint_row_id': 42244068,
#   'own_counts': {'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE': 3,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0},
#   'transfers': [{'from': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 3,
#     'row_id': 42244156},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'count': 3,
#     'row_id': 42805436}]},
#  188: {'creator': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmWPr6qj9o4xLyfKCHdFz6XUJDuExqsromksBxJtoRYmCB',
#   'mint_row_id': 42244196,
#   'own_counts': {'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE': 1,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0},
#   'transfers': [{'from': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42244257},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'count': 1,
#     'row_id': 42805560}]},
#  189: {'creator': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://Qmbv9h6MgSfzmNJ9MN4KfHKNWvFb9BjxZkDJfxKLUWhQwa',
#   'mint_row_id': 42244326,
#   'own_counts': {'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz1Qw7r9P5NDVm7KwAKQGFXGPpqH5RgDPYQx',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42244485}]},
#  190: {'creator': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#   'mint_count': 2,
#   'info_ipfs': 'ipfs://QmPe8etSj54Snj6tUQxGkYET1CcBfLUnL7QudKpw9W3Ux4',
#   'mint_row_id': 42244583,
#   'own_counts': {'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE': 2,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0},
#   'transfers': [{'from': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 2,
#     'row_id': 42244651},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1LovFrdT3D2uY5ijGnb16172szCqFazDCE',
#     'count': 2,
#     'row_id': 42806049}]},
#  191: {'creator': 'tz2MkhsWEcgCsaXJgrXAiYJE8y72qZT3xfHe',
#   'mint_count': 300,
#   'info_ipfs': 'ipfs://QmP255MU5jMF4YFmDjrrtnBGFazqzifRUvscKL5G4ZLVAD',
#   'mint_row_id': 42244733,
#   'own_counts': {'tz2MkhsWEcgCsaXJgrXAiYJE8y72qZT3xfHe': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 299,
#    'tz1YkVzUhf7YB9Dpfac1JCbqpxkxXrotQJeM': 1},
#   'transfers': [{'from': 'tz2MkhsWEcgCsaXJgrXAiYJE8y72qZT3xfHe',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 300,
#     'row_id': 42244983},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1YkVzUhf7YB9Dpfac1JCbqpxkxXrotQJeM',
#     'count': 1,
#     'row_id': 42430555}]},
#  192: {'creator': 'tz1cW7NSbACRKyzYR8pgCvTtAH8qEnv6AX1J',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmbjcmWWzUFnD1CvPjvt5ZcrUD7SrYDyk9jnXeTuHQamsU',
#   'mint_row_id': 42245509,
#   'own_counts': {'tz1cW7NSbACRKyzYR8pgCvTtAH8qEnv6AX1J': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1hUfjPUtaBMJnC9QBpPK64Mj9S4PSTEfkH': 1},
#   'transfers': [{'from': 'tz1cW7NSbACRKyzYR8pgCvTtAH8qEnv6AX1J',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42246168},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hUfjPUtaBMJnC9QBpPK64Mj9S4PSTEfkH',
#     'count': 1,
#     'row_id': 43714015}]},
#  193: {'creator': 'tz1bhMc5uPJynkrHpw7pAiBt6YMhQktn7owF',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmZEBppvxh5RQiKbBTGeDtLVU3RzpvWbAp4suo8w4muzcT',
#   'mint_row_id': 42245666,
#   'own_counts': {'tz1bhMc5uPJynkrHpw7pAiBt6YMhQktn7owF': 1,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0},
#   'transfers': [{'from': 'tz1bhMc5uPJynkrHpw7pAiBt6YMhQktn7owF',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42245785},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1bhMc5uPJynkrHpw7pAiBt6YMhQktn7owF',
#     'count': 1,
#     'row_id': 42469063}]},
#  194: {'creator': 'tz1WTb67VvXjMievFACoRZ7ABfvPkA9E9yjs',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmaUNM6sQVbfcCQhr4whExyG8Nir4ChpB9HHUq8UHbusZA',
#   'mint_row_id': 42245917,
#   'own_counts': {'tz1WTb67VvXjMievFACoRZ7ABfvPkA9E9yjs': 1},
#   'transfers': []},
#  195: {'creator': 'tz1PAoigCex9CcckWMimaWFAdKmN1AfwJ2Xa',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://Qma8Jwh1WBaeC8T8xasCBzHEzkeFMpXjnmfWC6XT95xFDF',
#   'mint_row_id': 42246026,
#   'own_counts': {'tz1PAoigCex9CcckWMimaWFAdKmN1AfwJ2Xa': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 10},
#   'transfers': [{'from': 'tz1PAoigCex9CcckWMimaWFAdKmN1AfwJ2Xa',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 10,
#     'row_id': 42248192}]},
#  196: {'creator': 'tz1WTb67VvXjMievFACoRZ7ABfvPkA9E9yjs',
#   'mint_count': 10000,
#   'info_ipfs': 'ipfs://QmX6GJFB4XjpnfNP8J2R18XjTxQrAsMDaTuBtrWkyyWxRF',
#   'mint_row_id': 42247126,
#   'own_counts': {'tz1WTb67VvXjMievFACoRZ7ABfvPkA9E9yjs': 9731,
#    'tz2TfSBYaFQaZeA65ek6mFU3na9x9XxVS1tN': 100,
#    'tz1NBpWeS2gVpwPpT9NUn9ifBRfriwicJT4y': 100,
#    'tz2Sc9vRbkCJkQUejnQVueU9DCsVAGEXgYZQ': 69},
#   'transfers': [{'from': 'tz1WTb67VvXjMievFACoRZ7ABfvPkA9E9yjs',
#     'to': 'tz2TfSBYaFQaZeA65ek6mFU3na9x9XxVS1tN',
#     'count': 100,
#     'row_id': 42393937},
#    {'from': 'tz1WTb67VvXjMievFACoRZ7ABfvPkA9E9yjs',
#     'to': 'tz1NBpWeS2gVpwPpT9NUn9ifBRfriwicJT4y',
#     'count': 100,
#     'row_id': 42394258},
#    {'from': 'tz1WTb67VvXjMievFACoRZ7ABfvPkA9E9yjs',
#     'to': 'tz2Sc9vRbkCJkQUejnQVueU9DCsVAGEXgYZQ',
#     'count': 69,
#     'row_id': 42394894}]},
#  197: {'creator': 'tz1YcRfmH4JsdvLzzijq1mh4FXjoHmh2ANEQ',
#   'mint_count': 7,
#   'info_ipfs': 'ipfs://QmU9ZwE9HBpRznV62cV6QekZrwY424oowMeAZds9hxsubA',
#   'mint_row_id': 42247749,
#   'own_counts': {'tz1YcRfmH4JsdvLzzijq1mh4FXjoHmh2ANEQ': 7},
#   'transfers': []},
#  198: {'creator': 'tz1ZZh4haUFRkDiinEhEtnKvaBiGyfpZg4QP',
#   'mint_count': 2,
#   'info_ipfs': 'ipfs://QmVWE21RiXRYHhGgumvaWSEQSpPVNNTqv7SJyCZgAmegUk',
#   'mint_row_id': 42247954,
#   'own_counts': {'tz1ZZh4haUFRkDiinEhEtnKvaBiGyfpZg4QP': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1UecmgMghaWovhh9EYfqTrK9gTtaiMtbzs': 1,
#    'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3': 1},
#   'transfers': [{'from': 'tz1ZZh4haUFRkDiinEhEtnKvaBiGyfpZg4QP',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42248201},
#    {'from': 'tz1ZZh4haUFRkDiinEhEtnKvaBiGyfpZg4QP',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42248264},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1UecmgMghaWovhh9EYfqTrK9gTtaiMtbzs',
#     'count': 1,
#     'row_id': 42250970},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2G5SBeAJVbiE1icji3P59Lx8EvcwMLEHp3',
#     'count': 1,
#     'row_id': 42267267}]},
#  199: {'creator': 'tz1WTb67VvXjMievFACoRZ7ABfvPkA9E9yjs',
#   'mint_count': 10000,
#   'info_ipfs': 'ipfs://QmX6GJFB4XjpnfNP8J2R18XjTxQrAsMDaTuBtrWkyyWxRF',
#   'mint_row_id': 42248163,
#   'own_counts': {'tz1WTb67VvXjMievFACoRZ7ABfvPkA9E9yjs': 10000},
#   'transfers': []},
#  200: {'creator': 'tz2K5UyvaMuNgiy5Zy8yVspTW6oXmchGvSey',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmQoKjEebtVCWJcvtc1DPtpxBNFC33Xwparkg5x973UZw8',
#   'mint_row_id': 42249980,
#   'own_counts': {'tz2K5UyvaMuNgiy5Zy8yVspTW6oXmchGvSey': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1Nu2Yn97X43BJyrBEcZ4kUNDw795NeHUWa': 1},
#   'transfers': [{'from': 'tz2K5UyvaMuNgiy5Zy8yVspTW6oXmchGvSey',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42250077},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Nu2Yn97X43BJyrBEcZ4kUNDw795NeHUWa',
#     'count': 1,
#     'row_id': 42253372}]},
#  201: {'creator': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmWyLV9WdRhHAPiGV8U6WgzBd6oxx9by8Vjn6Qx8Jdguqm',
#   'mint_row_id': 42250466,
#   'own_counts': {'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz1ae2d1BJt7YUqaaec6Xenh3mBqS7VjSZtK',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42250574}]},
#  202: {'creator': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#   'mint_count': 3,
#   'info_ipfs': 'ipfs://QmPQupHrPPY7s2Ktu6SmZJcs7nHizk7JxZ6iLEKVm1rVdv',
#   'mint_row_id': 42250959,
#   'own_counts': {'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 2,
#    'tz1VW5Wu4X7hDubM4cW3XfaPhJTL1ZuaXmfx': 0,
#    'tz1ZPvsrtvr1QQr4fDaqVChAiyCiacqWi5uy': 1},
#   'transfers': [{'from': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 3,
#     'row_id': 42251126},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#     'count': 3,
#     'row_id': 42498314},
# ...
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42608134}]},
#  1129: {'creator': 'tz2HdbFWnzRZ7B9fM2xZCYdZv8rM5frGKDCo',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmWy1xy3wrcPmXuBWZ5hhxDmQiG3ca5mrBr9C1kcqBNtEA',
#   'mint_row_id': 42607980,
#   'own_counts': {'tz2HdbFWnzRZ7B9fM2xZCYdZv8rM5frGKDCo': 3,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 5,
#    'tz1fmoyPS1sN91Qz41YVpqioZjJQJPYhCZyY': 1,
#    'tz2SWRcm87XVRaNqTyW3UxaLWwdvVG3xAZFQ': 1},
#   'transfers': [{'from': 'tz2HdbFWnzRZ7B9fM2xZCYdZv8rM5frGKDCo',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42608389},
#    {'from': 'tz2HdbFWnzRZ7B9fM2xZCYdZv8rM5frGKDCo',
#     'to': 'tz1fmoyPS1sN91Qz41YVpqioZjJQJPYhCZyY',
#     'count': 1,
#     'row_id': 42611466},
#    {'from': 'tz2HdbFWnzRZ7B9fM2xZCYdZv8rM5frGKDCo',
#     'to': 'tz2SWRcm87XVRaNqTyW3UxaLWwdvVG3xAZFQ',
#     'count': 1,
#     'row_id': 43116453}]},
#  1130: {'creator': 'tz1ZwnF6PNfsvRip6qNU5pgUke6tz8bxvdCJ',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmQuFTKWFQ19g6aPqnUkRPifq5pYQNWonszTpXzPTND8cq',
#   'mint_row_id': 42608008,
#   'own_counts': {'tz1ZwnF6PNfsvRip6qNU5pgUke6tz8bxvdCJ': 10},
#   'transfers': []},
#  1131: {'creator': 'tz1ZwnF6PNfsvRip6qNU5pgUke6tz8bxvdCJ',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmQuFTKWFQ19g6aPqnUkRPifq5pYQNWonszTpXzPTND8cq',
#   'mint_row_id': 42608042,
#   'own_counts': {'tz1ZwnF6PNfsvRip6qNU5pgUke6tz8bxvdCJ': 10},
#   'transfers': []},
#  1132: {'creator': 'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://Qmdb8UVcpWwbJh1ASQYpD3PMoXdcyviJpQSvQiN9U2wBGm',
#   'mint_row_id': 42608560,
#   'own_counts': {'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42608703}]},
#  1133: {'creator': 'tz1idFEncPpXXmpMUqw8ip2vSVaxqR7aNjh7',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmVe5wE3WgyZqVQHzNaby7RDBWAFcdKVfwCVgJRdsMdfdt',
#   'mint_row_id': 42608669,
#   'own_counts': {'tz1idFEncPpXXmpMUqw8ip2vSVaxqR7aNjh7': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 5},
#   'transfers': [{'from': 'tz1idFEncPpXXmpMUqw8ip2vSVaxqR7aNjh7',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42608878}]},
#  1134: {'creator': 'tz1VPAcK6PRLz2i2R7A6dPLurWoSNBARw6VN',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmWEEN4ZMGS3Lc4AifPnLQaKDA5HSuFgfUAgiykmPAYynG',
#   'mint_row_id': 42608706,
#   'own_counts': {'tz1VPAcK6PRLz2i2R7A6dPLurWoSNBARw6VN': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp': 1},
#   'transfers': [{'from': 'tz1VPAcK6PRLz2i2R7A6dPLurWoSNBARw6VN',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42609047},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1VPAcK6PRLz2i2R7A6dPLurWoSNBARw6VN',
#     'count': 1,
#     'row_id': 42611326},
#    {'from': 'tz1VPAcK6PRLz2i2R7A6dPLurWoSNBARw6VN',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42611553},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1VPAcK6PRLz2i2R7A6dPLurWoSNBARw6VN',
#     'count': 1,
#     'row_id': 42616656},
#    {'from': 'tz1VPAcK6PRLz2i2R7A6dPLurWoSNBARw6VN',
#     'to': 'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp',
#     'count': 1,
#     'row_id': 42631737}]},
#  1135: {'creator': 'tz1afureobPug5SAYP5rukZYDnQmeGR5g4BY',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://Qmd6YeNdRqW3syW27GuB8rrKnhb81r2NfpaTdK5TDTceR9',
#   'mint_row_id': 42608735,
#   'own_counts': {'tz1afureobPug5SAYP5rukZYDnQmeGR5g4BY': 1},
#   'transfers': []},
#  1136: {'creator': 'tz1N11Gwgiu3wivGUwE7LcA8gz8i3qiJ73k8',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmWTiypSMJAbPf4cyWz45YRZVrSSQM81A1Gpm5tCM32Nbw',
#   'mint_row_id': 42608758,
#   'own_counts': {'tz1N11Gwgiu3wivGUwE7LcA8gz8i3qiJ73k8': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz1N11Gwgiu3wivGUwE7LcA8gz8i3qiJ73k8',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42634261}]},
#  1137: {'creator': 'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmVGRgHGNhKJAWPmK9P6AFYkW59hVLSAcyauUbNa2gq2Nf',
#   'mint_row_id': 42608815,
#   'own_counts': {'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42608943}]},
#  1138: {'creator': 'tz1V84gmD8MsmLuCfT9M1LDaTjpJb4eAejvM',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmZ7uYnc2bSR5tJbAMbW9SLwH62fy3xDSWFYD2povS4eT7',
#   'mint_row_id': 42609078,
#   'own_counts': {'tz1V84gmD8MsmLuCfT9M1LDaTjpJb4eAejvM': 0,
#    'tz1bH9hv3W4pNWg5EM3CxCutnnF42QvFfiSP': 1,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1,
#    'tz1c5nt7L8yzPioKJhXT41DhbrNhd6SN3Ysj': 1,
#    'tz1hhG3vN2NCoPZepvEbKHBFQ5denwNJwHXP': 1,
#    'tz1ipeQ1tSrs13y2j23njJotgVSVLtfvxS9a': 1},
#   'transfers': [{'from': 'tz1V84gmD8MsmLuCfT9M1LDaTjpJb4eAejvM',
#     'to': 'tz1bH9hv3W4pNWg5EM3CxCutnnF42QvFfiSP',
#     'count': 1,
#     'row_id': 42609241},
#    {'from': 'tz1V84gmD8MsmLuCfT9M1LDaTjpJb4eAejvM',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 4,
#     'row_id': 42610183},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1c5nt7L8yzPioKJhXT41DhbrNhd6SN3Ysj',
#     'count': 1,
#     'row_id': 42610936},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hhG3vN2NCoPZepvEbKHBFQ5denwNJwHXP',
#     'count': 1,
#     'row_id': 42614166},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1ipeQ1tSrs13y2j23njJotgVSVLtfvxS9a',
#     'count': 1,
#     'row_id': 43082014}]},
#  1139: {'creator': 'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmZSJjUTzm1qdH6M6jnnYHcW9sRNNFG4pP2bTzzH5LjYtT',
#   'mint_row_id': 42609080,
#   'own_counts': {'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42613601}]},
#  1140: {'creator': 'tz1hv8sQYPXy1g2E2jaCrmqzjRoGLU1HcAoN',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmXAm8zN33EBfqEXtBBWkjvL9TjotJ3ou5rwV9KCXU8Kdc',
#   'mint_row_id': 42609244,
#   'own_counts': {'tz1hv8sQYPXy1g2E2jaCrmqzjRoGLU1HcAoN': 5,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 5},
#   'transfers': [{'from': 'tz1hv8sQYPXy1g2E2jaCrmqzjRoGLU1HcAoN',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 10,
#     'row_id': 42611887},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hv8sQYPXy1g2E2jaCrmqzjRoGLU1HcAoN',
#     'count': 10,
#     'row_id': 43701233},
#    {'from': 'tz1hv8sQYPXy1g2E2jaCrmqzjRoGLU1HcAoN',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 43702451}]},
#  1141: {'creator': 'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmQya6JvFPKj4kLFhAC1EQtFSXx7PxZwnCj7UzMn9mjG1h',
#   'mint_row_id': 42609275,
#   'own_counts': {'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz2ERCwCgNjKJ59Z3WowF9nsS8ps3tXkBUak',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42613743}]},
#  1142: {'creator': 'tz1iyFi4WjSttoja7Vi1EJYMEKKSebQyMkF9',
#   'mint_count': 2,
#   'info_ipfs': 'ipfs://QmcyYXjyfkPRZaToUKpEQ5wGjoB1U4RJRnbvrXj8WbggmE',
#   'mint_row_id': 42609277,
#   'own_counts': {'tz1iyFi4WjSttoja7Vi1EJYMEKKSebQyMkF9': 1,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz1iyFi4WjSttoja7Vi1EJYMEKKSebQyMkF9',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42610330}]},
#  1143: {'creator': 'tz1cr7UMrontkJ9PWnBqXGz4ggQV9MQHwBtH',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmfA2hXNoWaYRGkvmpe18SSFKBzDLNqbjva99cN59ao1Fd',
#   'mint_row_id': 42609463,
#   'own_counts': {'tz1cr7UMrontkJ9PWnBqXGz4ggQV9MQHwBtH': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 7,
#    'tz1YRG68NdqtAcsFEwTUw6FsSsiBb5kagEDo': 1,
#    'tz1TSWEDs9wcBx2KiRzVzyzECsNpRiZaLJ1D': 1,
#    'tz1fyAVLtX5CJvEaBo6wgiAZPW42Thhwy5Z9': 1},
#   'transfers': [{'from': 'tz1cr7UMrontkJ9PWnBqXGz4ggQV9MQHwBtH',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 10,
#     'row_id': 42610042},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1YRG68NdqtAcsFEwTUw6FsSsiBb5kagEDo',
#     'count': 1,
#     'row_id': 42714967},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1TSWEDs9wcBx2KiRzVzyzECsNpRiZaLJ1D',
#     'count': 1,
#     'row_id': 43122480},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1fyAVLtX5CJvEaBo6wgiAZPW42Thhwy5Z9',
#     'count': 1,
#     'row_id': 43654916}]},
#  1144: {'creator': 'tz1ZvTGYH5EBwgmaYngELeUw1qzgQRJLKoDM',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmUtP9969aUYppHmvPrZMg3STuVRHGNeJ4axWWcnWLq6uV',
#   'mint_row_id': 42610186,
#   'own_counts': {'tz1ZvTGYH5EBwgmaYngELeUw1qzgQRJLKoDM': 5,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1YRG68NdqtAcsFEwTUw6FsSsiBb5kagEDo': 1,
#    'tz1Lgpkv5cW58YWk6B2rXL5h4nbCYXASHiML': 1,
#    'tz1cjHCorsyNqN3cWWKoYpzycBJmpifyoWd6': 1,
#    'tz1YjmR1StFsGGJZ3jm6YuG7B1uNP3i6Bss4': 1,
#    'tz1VY543f4YJvbCp2QpgvspvRtP5ucQJi4oZ': 1},
#   'transfers': [{'from': 'tz1ZvTGYH5EBwgmaYngELeUw1qzgQRJLKoDM',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42610332},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1YRG68NdqtAcsFEwTUw6FsSsiBb5kagEDo',
#     'count': 1,
#     'row_id': 42610655},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Lgpkv5cW58YWk6B2rXL5h4nbCYXASHiML',
#     'count': 1,
#     'row_id': 42610819},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1cjHCorsyNqN3cWWKoYpzycBJmpifyoWd6',
#     'count': 1,
#     'row_id': 42611149},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1YjmR1StFsGGJZ3jm6YuG7B1uNP3i6Bss4',
#     'count': 1,
#     'row_id': 42622271},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1VY543f4YJvbCp2QpgvspvRtP5ucQJi4oZ',
#     'count': 1,
#     'row_id': 42857073}]},
#  1145: {'creator': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmcNwnmmErRyHU2SaKkCaU4DxD1uZ9DZmmWy3bBKjsTWTR',
#   'mint_row_id': 42610484,
#   'own_counts': {'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC': 1,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 9},
#   'transfers': [{'from': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42610692},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#     'count': 5,
#     'row_id': 42667736},
#    {'from': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 8,
#     'row_id': 42667990},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#     'count': 8,
#     'row_id': 43499295},
#    {'from': 'tz1PYqfNnkpZydtSY2Tn3Rv8mjkgUpHJpFXC',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 9,
#     'row_id': 43499411}]},
#  1146: {'creator': 'tz1ZZh4haUFRkDiinEhEtnKvaBiGyfpZg4QP',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmS2TxCY4DtqsCwxmAZ2upCFZx5bwby72AurHdrk8NkqzA',
#   'mint_row_id': 42610566,
#   'own_counts': {'tz1ZZh4haUFRkDiinEhEtnKvaBiGyfpZg4QP': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0,
#    'tz1YRG68NdqtAcsFEwTUw6FsSsiBb5kagEDo': 1},
#   'transfers': [{'from': 'tz1ZZh4haUFRkDiinEhEtnKvaBiGyfpZg4QP',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42610659},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1YRG68NdqtAcsFEwTUw6FsSsiBb5kagEDo',
#     'count': 1,
#     'row_id': 42610884}]},
#  1147: {'creator': 'tz1ZvTGYH5EBwgmaYngELeUw1qzgQRJLKoDM',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmYYba5gX8SxMngDvAdm8gVwrzZ2Sbhj88MS1XbesxLyAs',
#   'mint_row_id': 42610663,
#   'own_counts': {'tz1ZvTGYH5EBwgmaYngELeUw1qzgQRJLKoDM': 5,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 5},
#   'transfers': [{'from': 'tz1ZvTGYH5EBwgmaYngELeUw1qzgQRJLKoDM',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42610891}]},
#  1148: {'creator': 'tz1Wy1CYHmF67wy4zz4QTxph5XzK3EgXPWFp',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmfBRN91iYfu4cBVzY7diGHZBCg5vNUVv8AfV355qe8Pf6',
#   'mint_row_id': 42610740,
#   'own_counts': {'tz1Wy1CYHmF67wy4zz4QTxph5XzK3EgXPWFp': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 5},
#   'transfers': [{'from': 'tz1Wy1CYHmF67wy4zz4QTxph5XzK3EgXPWFp',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42620552}]},
#  1149: {'creator': 'tz1VbkEEmrxQgMVWeauZF2KD1BaHfrvSHp5z',
#   'mint_count': 10,
#   'info_ipfs': 'ipfs://QmUKLMEwD5LqDAk6GzHrua9aReDCon4sf6bnNtXZfY5gsi',
#   'mint_row_id': 42610742,
#   'own_counts': {'tz1VbkEEmrxQgMVWeauZF2KD1BaHfrvSHp5z': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 5,
#    'tz1c3hFmjFSwunjLHECnYyjr42KRt5YiHrGX': 1,
#    'tz1dC1gNTYrpRx8wKdZFhUX7oK8h6o2j6UdV': 1,
#    'tz2Pkj2xWJovKKCsABjnr3NbyMVJTMBkpTvb': 1,
#    'tz2VN3fWzqHE44F6zedJB7UtALKEh5WhqAJJ': 1,
#    'tz1eCX4smQ3LbxwDR3pqNoLQvNNKiHJtpwYz': 1},
#   'transfers': [{'from': 'tz1VbkEEmrxQgMVWeauZF2KD1BaHfrvSHp5z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 2,
#     'row_id': 42610889},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1c3hFmjFSwunjLHECnYyjr42KRt5YiHrGX',
#     'count': 1,
#     'row_id': 42612664},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1dC1gNTYrpRx8wKdZFhUX7oK8h6o2j6UdV',
#     'count': 1,
#     'row_id': 42615175},
#    {'from': 'tz1VbkEEmrxQgMVWeauZF2KD1BaHfrvSHp5z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 2,
#     'row_id': 42644384},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz2Pkj2xWJovKKCsABjnr3NbyMVJTMBkpTvb',
#     'count': 1,
#     'row_id': 42681035},
#    {'from': 'tz1VbkEEmrxQgMVWeauZF2KD1BaHfrvSHp5z',
#     'to': 'tz2VN3fWzqHE44F6zedJB7UtALKEh5WhqAJJ',
#     'count': 1,
#     'row_id': 42702150},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1eCX4smQ3LbxwDR3pqNoLQvNNKiHJtpwYz',
#     'count': 1,
#     'row_id': 43188859},
#    {'from': 'tz1VbkEEmrxQgMVWeauZF2KD1BaHfrvSHp5z',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 43191441}]},
#  1150: {'creator': 'tz1c5nt7L8yzPioKJhXT41DhbrNhd6SN3Ysj',
#   'mint_count': 5,
#   'info_ipfs': 'ipfs://QmPUtLYThB6YdWP9hsEKXffKw9MKzyUPM29wioC6fXAQ99',
#   'mint_row_id': 42610745,
#   'own_counts': {'tz1c5nt7L8yzPioKJhXT41DhbrNhd6SN3Ysj': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 2,
#    'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp': 1,
#    'tz1a92ZVmHDSqZ2dYbcrTZG9baK7bXSMRazZ': 1,
#    'tz1Pu8zRmNghAHzWxsT9Cy2qXHxkCrHcB3vc': 1},
#   'transfers': [{'from': 'tz1c5nt7L8yzPioKJhXT41DhbrNhd6SN3Ysj',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 5,
#     'row_id': 42611034},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1hb9PiWxQEf6J9xevPsUM6dkuCLnhDMvsp',
#     'count': 1,
#     'row_id': 42611239},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1a92ZVmHDSqZ2dYbcrTZG9baK7bXSMRazZ',
#     'count': 1,
#     'row_id': 43216888},
#    {'from': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'to': 'tz1Pu8zRmNghAHzWxsT9Cy2qXHxkCrHcB3vc',
#     'count': 1,
#     'row_id': 43653093}]},
#  1151: {'creator': 'tz1efcNMdHxSrMPiSeLFrbdUQr8eWwWJmGnW',
#   'mint_count': 1,
#   'info_ipfs': 'ipfs://QmePkEGk55hP6NGkk2FUT4iFLb22Gf9Zto1e1CghE7JysH',
#   'mint_row_id': 42611143,
#   'own_counts': {'tz1efcNMdHxSrMPiSeLFrbdUQr8eWwWJmGnW': 0,
#    'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 1},
#   'transfers': [{'from': 'tz1efcNMdHxSrMPiSeLFrbdUQr8eWwWJmGnW',
#     'to': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
#     'count': 1,
#     'row_id': 42611362}]},
#  ...}

# %%
import requests

req = requests.get(f'https://api.tzkt.io/v1/accounts/tz1RnsQi6BaYpm6sMMTkVqGk5Jk6BKpmTp8C/metadata')
req.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-72-94baa4c95fe8> in <module>()
#       2
#       3 req = requests.get(f'https://api.tzkt.io/v1/accounts/tz1RnsQi6BaYpm6sMMTkVqGk5Jk6BKpmTp8C/metadata')
# ----> 4 req.json()
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
req.status_code
# Out:
# 204

# %%
import sys
import time
import datetime
from pathlib import Path
from tqdm import tqdm
import requests
from collections import Counter

repo_dir = Path('..').resolve()
assert repo_dir.name == 'hicetnunc-dataset', repo_dir
if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

import lib.utils
import lib.iter_tr


stamp_step = 100000
config_hash = '4ff66f8cc8'
transactions_dir = repo_dir / 'cache' / 'transactions' / config_hash
assert transactions_dir.is_dir()

name2addr = {
    'art_house_contract': 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9',
    'curate_contract': 'KT1TybhR7XraG75JFYKSrh7KnxukMBT5dor6',
    'hdao_contract': 'KT1AFA2mwNUMNd4SsujE1YYp29vd8BZejyKW',
    'nft_contract': 'KT1RJ6PbjHpwc3M5rw5s2Nbmefwbuwbdxton',
    'comission_wallet': 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw',
}
addr2name = { addr: name for name, addr in name2addr.items() }

# %%
money_trs = []

for tr in lib.iter_tr.iter_tr(transactions_dir, stamp_step):
    tr_addrs = set()
    tr_volume = 0
    for op in tr['ops']:
        tr_volume += op['volume']
        tr_addrs.add(op['sender'])
        if 'receiver' in op:
            tr_addrs.add(op['receiver'])
    if not (tr_addrs & known_addrs) or tr_volume == 0:
        continue
    money_trs.append(tr)

len(money_trs)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:04<00:00,  4.57it/s]
# 10630

# %%
def get_tr_money_delta(tr):
    res = {}
    for op in tr['ops']:
        if op['volume'] == 0:
            continue
        sender, receiver = op['sender'], op['receiver']
        res[sender] = res.get(sender, 0) - op['volume']
        res[receiver] = res.get(receiver, 0) + op['volume']
    return res


def get_addr_signature(addr):
    return addr2name.get(addr, '*')


def get_op_signature(op):
    if op['status'] != 'applied':
        return op['status']
    if op['type'] != 'transaction':
        return op['type']
    call = op.get('parameters', {'call': ''})['call']
    if op['volume'] > 0:
        return (
            call,
            get_addr_signature(op['sender']) + ' > ' + get_addr_signature(op['receiver']),
        )
    return call


def get_tr_signature(tr):
    ext_count = 0
    res = tuple()
    has_any_applied = False
    for op in tr['ops']:
        if op['type'] == 'reveal':
            continue
        if op['status'] == 'applied':
            has_any_applied = True
        if op['sender'] not in addr2name and op.get('receiver') not in addr2name:
            ext_count += 1
        else:
            res += (get_op_signature(op),)
    if not has_any_applied:
        return tr['ops'][0]['status']
    res = (ext_count > 0,) + res
    return res


from collections import Counter

tr_signatures = Counter()

for tr in money_trs:
    tr_signature = get_tr_signature(tr)
    if tr_signature == (False, ('', 'comission_wallet > *')):
        # assert len(tr['ops']) == 1
        # print(tr['hash'])
        # print(tr['time'], tr['ops'][0]['receiver'], tr['ops'][0]['volume'])
        pass
    if tr_signature == (False,
        ('collect', '* > art_house_contract'),
        ('', 'art_house_contract > *'),
        ('', 'art_house_contract > comission_wallet'),
        ('', 'art_house_contract > *'),
        'hDAO_batch',
        'transfer'):
            break
    tr_signatures[tr_signature] += 1

tr_signatures.most_common()
# Out:
# [((True, ('', '* > comission_wallet')), 2),
#  ((False,
#    ('collect', 'comission_wallet > art_house_contract'),
#    ('', 'art_house_contract > *'),
#    ('', 'art_house_contract > comission_wallet'),
#    ('', 'art_house_contract > *'),
#    'hDAO_batch',
#    'transfer'),
#   1)]

# %%
print(get_tr_money_delta(tr))
# Out:
# {'tz1Rux3pGrp2KpZUBKvg3VQ4edRYVJsapr4z': -10, 'KT1Hkg5qeNhfwpKW4fXvq7HGZB9z2EnmCCA9': 0.0, 'tz1ZdMfzmWLb8mu22jE7rZ8Y3t9iKezM68cq': 9.75, 'tz1UBZUkXpKGhYsP5KtzDNqLLchwF4uHrGjw': 0.25}
